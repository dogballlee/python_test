# %%
import pandas as pd
import numpy as np

# %%
# pandas.pivot_table(data, values=None, index=None, 
#                                     columns=None, aggfunc='mean', fill_value=None, 
#                                     margins=False, dropna=True, margins_name='All', 
#                                     observed=False)[source]

df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
                         "bar", "bar", "bar", "bar"],
                   "B": ["one", "one", "one", "two", "two",
                         "one", "one", "two", "two"],
                   "C": ["small", "large", "large", "small",
                         "small", "large", "small", "small",
                         "large"],
                   "D": [1, 2, 2, 3, 3, 4, 5, 6, 7],
                   "E": [2, 4, 5, 5, 6, 6, 8, 9, 9]})
df
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9

# %%
table = pd.pivot_table(df, index=['A', 'B'], columns='C', values='D', aggfunc=np.sum, fill_value=0)    #很怪，补全nan居然用fill_value不用fill_na...
# print(table)
# print(table.index)
# print(table.columns)
table
# Out:
# C        large  small
# A   B
# bar one      4      5
#     two      7      6
# foo one      4      1
#     two      0      6

# %%
table1 = pd.pivot_table(df, values=['D', 'E'], index=['A', 'C'], aggfunc={'D': np.mean, 'E': np.mean}) 
table1
# Out:
#                   D         E
# A   C
# bar large  5.500000  7.500000
#     small  5.500000  8.500000
# foo large  2.000000  4.500000
#     small  2.333333  4.333333

# %%
table2 = pd.pivot_table(df, values=['D', 'E'], index=['A', 'C'], aggfunc={'D': np.mean, 'E': [max, min, np.mean]})
table2
# Out:
#                   D    E
#                mean  max      mean  min
# A   C
# bar large  5.500000  9.0  7.500000  6.0
#     small  5.500000  9.0  8.500000  8.0
# foo large  2.000000  5.0  4.500000  4.0
#     small  2.333333  6.0  4.333333  2.0

# %%
#crosstab可以理解为一种特殊的pivot_table，用于计算分组的频率（也可以通过value和aggfunc按计算规则计算）
a = np.array(["foo", "foo", "foo", "foo", "bar", "bar","bar", "bar", "foo", "foo", "foo"], dtype=object)
b = np.array(["one", "one", "one", "two", "one", "one","one", "two", "two", "two", "one"], dtype=object)
c = np.array(["dull", "dull", "shiny", "dull", "dull", "shiny","shiny", "dull", "shiny", "shiny", "shiny"],dtype=object)
# df0 = pd.DataFrame({'A':a, 'B': b, 'C': c})
df = pd.crosstab(a, [b, c], rownames=['a'], colnames=['b', 'c'])
# df0
df
# Out:
# b    one        two
# c   dull shiny dull shiny
# a
# bar    1     2    1     0
# foo    2     2    1     2

# %%
foo = pd.Categorical(['a', 'b'], categories=['a', 'b', 'c'])
bar = pd.Categorical(['d', 'e'], categories=['d', 'e', 'f'])
pd.crosstab(foo, bar, dropna=0)    #crosstab中默认的dropna=1
# Out:
# col_0  d  e  f
# row_0
# a      1  0  0
# b      0  1  0
# c      0  0  0

# %%
pd.cut(np.array([1, 7, 5, 4, 6, 3]), 3)
# Out:
# [(0.994, 3.0], (5.0, 7.0], (3.0, 5.0], (3.0, 5.0], (5.0, 7.0], (0.994, 3.0]]
# Categories (3, interval[float64]): [(0.994, 3.0] < (3.0, 5.0] < (5.0, 7.0]]
